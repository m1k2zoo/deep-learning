# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Load data and replace -1 labels by 0
data = np.loadtxt('data.dat')
x = data[:, 0:-1]
y = data[:, -1].reshape(x.shape[0], 1)
y[y == -1] = 0

def my_model(x_train, y_train, opt = 'SGD', act = 'relu', num_epochs = 1000):
    # callback to stop the training when converged
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=8) # 8 for Adam if not sigmoid
    # weight and bias initializers
    weights = tf.keras.initializers.GlorotUniform(seed=99)
    biases = tf.keras.initializers.Zeros()
    # create the model
    model = tf.keras.models.Sequential([
      tf.keras.Input(shape=(2,)),
      tf.keras.layers.Dense(5, bias_initializer=biases, kernel_initializer=weights, activation=act),
      tf.keras.layers.Dense(1, bias_initializer=biases, kernel_initializer=weights, activation='sigmoid')
    ])
    # instantiate the optimizer
    if(opt == 'SGD'):
        optmz = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.0)
    elif(opt == 'Adam'):
        optmz = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.99)
    elif(opt == 'RMSprop'):
        optmz = tf.keras.optimizers.RMSprop(learning_rate=0.001, epsilon=1e-06)
    # learn the parameters
    model.compile(optimizer=optmz, loss='binary_crossentropy',metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=num_epochs, verbose=1)
    # predict on the given point
    prediction = model.predict(tf.constant(np.array([0.8, 0.2]).reshape(1,2)))
    
    return history, 1*(prediction>0.5)

# %%
import time
t0 = time.time()
hist, pred = my_model(x, y, opt='SGD', act='sigmoid', num_epochs=5000)
t1 = time.time()
plt.plot(hist.history['accuracy']);
# Out:
# Epoch 1/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7209 - accuracy: 0.4930
# Epoch 2/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7123 - accuracy: 0.4930
# Epoch 3/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7062 - accuracy: 0.4930
# Epoch 4/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.4930
# Epoch 5/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.4930
# Epoch 6/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4920
# Epoch 7/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6971 - accuracy: 0.4720
# Epoch 8/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.4460
# Epoch 9/5000
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6958 - accuracy: 0.3880
# Epoch 10/5000
# ...

# %%
len(hist.history['accuracy'])
1e-3
# Out:
# 0.001

# %%
print("The order by which I'm computing the results is as follows:")
optimizers = ['SGD', 'RMSprop', 'Adam']
activations = ['relu', 'tanh', 'sigmoid']
k = 0
a = np.zeros((1000,9))
for i in range(3):
    activation = activations[i]
    print()
    for j in range(3):
        optimizer = optimizers[j]
        print('act: ' + activation + ', opt: ' + optimizer)
        k+=1
# Out:
# The order by which I'm computing the results is as follows:
#
# act: relu, opt: SGD
# act: relu, opt: RMSprop
# act: relu, opt: Adam
#
# act: tanh, opt: SGD
# act: tanh, opt: RMSprop
# act: tanh, opt: Adam
#
# act: sigmoid, opt: SGD
# act: sigmoid, opt: RMSprop
# act: sigmoid, opt: Adam

# %%
import time
k = 0
epochs = 2000
accuracy_histories = np.zeros((epochs,9))
predictions = np.zeros((1, 9))
training_times = np.zeros((1,9))
for i in range(3):
    activation = activations[i]
    for j in range(3):
        optimizer = optimizers[j]
        t0 = time.time()
        hist, pred = my_model(x, y, opt=optimizer, act=activation, num_epochs=epochs)
        t1 = time.time()
        accuracy_histories[:,k], predictions[:,k], training_times[:,k] = hist.history['accuracy'], pred, t1-t0
        k+=1

# %%
print(np.sum(training_times))
1*(predictions > 0.5)
# Out:
# 264.7407088279724
# array([[1, 1, 1, 1, 1, 1, 0, 1, 1]])

# %%
fig, axs = plt.subplots(nrows=3, ncols=3)
fig.set_figheight(15)
fig.set_figwidth(20)
axs = axs.ravel()
a = 0
for i in range(3):
    s1 = 'act: '+ activations[i] + ', opt: SGD'
    s2 = 'act: '+ activations[i] + ', opt: RMSprop'
    s3 = 'act: '+ activations[i] + ', opt: Adam'
    
    # visualize
    axs[a].plot(accuracy_histories[:,a])
    axs[a].set_title(s1)
    a += 1
    
    # visualize 
    axs[a].plot(accuracy_histories[:,a])
    axs[a].set_title(s2)
    a += 1
    
    # visualize 
    axs[a].plot(accuracy_histories[:,a])
    axs[a].set_title(s3)
    a += 1

# %%
for i in range(10):
    print(model.predict(tf.constant(x[i+989].reshape(1,2))) > 0.5)
    print(y[i+989])
    print()
# Out:
# [[False]]
# [0.]
#
# [[ True]]
# [1.]
#
# [[False]]
# [0.]
#
# [[ True]]
# [1.]
#
# [[ True]]
# [1.]
#
# [[ True]]
# [1.]
#
# [[ True]]
# [1.]
#
# [[False]]
# [0.]
#
# [[ True]]
# [1.]
#
# [[False]]
# [1.]

# %%
training_times[:,2]+training_times[:,5]+training_times[:,8]
# Out:
# array([85.60243511])

# %%
accuracy_histories[:,8][1900]
# Out:
# 0.9710000157356262
